# %%
# !pip install numpy matplotlib pillow
# Out:
# Requirement already satisfied: numpy in c:\users\mc_dkaralius26\appdata\local\anaconda3\lib\site-packages (2.1.3)
# Requirement already satisfied: matplotlib in c:\users\mc_dkaralius26\appdata\local\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: pillow in c:\users\mc_dkaralius26\appdata\local\anaconda3\lib\site-packages (11.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mc_dkaralius26\appdata\local\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\mc_dkaralius26\appdata\local\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mc_dkaralius26\appdata\local\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mc_dkaralius26\appdata\local\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\mc_dkaralius26\appdata\local\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mc_dkaralius26\appdata\local\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mc_dkaralius26\appdata\local\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\mc_dkaralius26\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# 1. Setup the figure and axes
fig, ax = plt.subplots()
# Set limits to make sure the oscillation fits and is centered
ax.set_xlim(0, 2 * np.pi)
ax.set_ylim(-1.1, 1.1)
ax.set_title("oscillating sine wave demo")
ax.set_xlabel("position (x)")
ax.set_ylabel("amplitude (y)")

# Initialize the line plot (line,) is needed for blitting
line, = ax.plot([], [], lw=2)

# Data for the wave
x = np.linspace(0, 2 * np.pi, 100)

# 2. Initialization function (returns the line object)
def init():
    line.set_data([], [])
    return line,

# 3. Animation function (updates the line object for each frame)
def animate(frame):
    # Create an oscillating wave by shifting the phase based on the frame number
    # frame / 10.0 controls the speed of the oscillation
    y = np.sin(x + frame / 10.0)
    line.set_data(x, y)
    return line,

# 4. Create the animation
# frames=100 sets the number of frames
# interval=50 means 50ms per frame (20 frames per second)
ani = FuncAnimation(
    fig,
    animate,
    init_func=init,
    frames=100,
    interval=150,
    blit=True
)

# 5. Save the animation as a GIF
ani.save('oscillating_wave.gif', writer='pillow', fps=60, dpi=100)

# The figure is closed to prevent it from displaying during execution
plt.close(fig)
